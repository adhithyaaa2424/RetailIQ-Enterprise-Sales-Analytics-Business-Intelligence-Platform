# %%
# RetailIQ

# ETL Phase

## Notebook 01 – Customer Data Generation

### Objective

Generate realistic customer data for the RetailIQ project using the Faker library.
The generated dataset will later be:

- Validated
- Exported to CSV
- Loaded into PostgreSQL
- Used for SQL analysis
- Used in Power BI dashboards
# Out:
#   Cell In[2], line 9
#     Generate realistic customer data for the RetailIQ project using the Faker library.
#              ^
# SyntaxError: invalid syntax

# %%
import sys
from pathlib import Path

project_python = Path.cwd().parent.resolve()

if str(project_python) not in sys.path:
    sys.path.insert(0, str(project_python))

# %%
import importlib
import src.config as config

importlib.reload(config)
# Out:
# <module 'src.config' from 'C:\\Users\\Welcome\\Desktop\\RetailIQ\\Python\\src\\config.py'>

# %%
import pandas as pd

from src.config import *
from src.generators import generate_customers

# %%
NUMBER_OF_CUSTOMERS = 10

# %%
customers_df = generate_customers(NUMBER_OF_CUSTOMERS)

customers_df.head()
# Out:
#   first_name   last_name  gender  age                        email  \
# 0      Vidhi       Edwin  Female   37   chandervedhika@example.com
# 1    Vedhika  Narasimhan    Male   20       bainshenry@example.net
# 2   Pratyush      Karnik  Female   70  sundaramgautami@example.com
# 3      Laban   Chowdhury    Male   61      gramanathan@example.com
# 4    Gaurang       Magar  Female   57         andrew21@example.org
#
#            phone       city          state country  join_date
# 0  +915425744261  Kharagpur      Rajasthan   India 2023-07-15
# 1  +912553941079     Shimla          Assam   India 2021-10-23
# 2    04688187056  Sambalpur      Rajasthan   India 2026-05-31
# 3    04100223212  Anantapur  Uttar Pradesh   India 2025-03-24
# 4    03214022598     Bokaro      Rajasthan   India 2023-01-26

# %%
customers_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   first_name  10 non-null     str
#  1   last_name   10 non-null     str
#  2   gender      10 non-null     str
#  3   age         10 non-null     int64
#  4   email       10 non-null     str
#  5   phone       10 non-null     str
#  6   city        10 non-null     str
#  7   state       10 non-null     str
#  8   country     10 non-null     str
#  9   join_date   10 non-null     datetime64[s]
# dtypes: datetime64[s](1), int64(1), str(8)
# memory usage: 932.0 bytes

# %%
customers_df.isnull().sum()
# Out:
# first_name    0
# last_name     0
# gender        0
# age           0
# email         0
# phone         0
# city          0
# state         0
# country       0
# join_date     0
# dtype: int64

# %%
customers_df.describe(include="all")
# Out:
#        first_name last_name  gender        age                       email  \
# count          10        10      10  10.000000                          10
# unique         10        10       2        NaN                          10
# top         Vidhi     Edwin  Female        NaN  chandervedhika@example.com
# freq            1         1       5        NaN                           1
# mean          NaN       NaN     NaN  42.000000                         NaN
# min           NaN       NaN     NaN  18.000000                         NaN
# 25%           NaN       NaN     NaN  24.250000                         NaN
# 50%           NaN       NaN     NaN  37.500000                         NaN
# 75%           NaN       NaN     NaN  60.000000                         NaN
# max           NaN       NaN     NaN  70.000000                         NaN
# std           NaN       NaN     NaN  19.379256                         NaN
#
# ...

# %%
customers_df["email"].duplicated().sum()
# Out:
# np.int64(0)

# %%
customers_df.sample(5)
# Out:
#   first_name   last_name  gender  age                           email  \
# 1    Vedhika  Narasimhan    Male   20          bainshenry@example.net
# 9     Aayush       Dewan    Male   62            suhani16@example.net
# 6    Brijesh        Tata    Male   38  mukhopadhyaylipika@example.net
# 2   Pratyush      Karnik  Female   70     sundaramgautami@example.com
# 7    Krishna      Butala  Female   37            osachdev@example.net
#
#            phone         city              state country  join_date
# 1  +912553941079       Shimla              Assam   India 2021-10-23
# 9  +910910049632    Faridabad       Chhattisgarh   India 2026-03-17
# 6  +911199379856   Davanagere  Arunachal Pradesh   India 2022-06-05
# 2    04688187056    Sambalpur          Rajasthan   India 2026-05-31
# 7  +917899266288  Mahbubnagar       Chhattisgarh   India 2021-07-18

# %%
import src.validators as validators

print(dir(validators))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'date', 'pd', 'validate_age_range', 'validate_duplicate_emails', 'validate_future_join_dates', 'validate_gender', 'validate_missing_values']

# %%
validate_missing_values(customers_df)
# Out:
# ...
# Missing Value Report
# ...
# first_name    0
# last_name     0
# gender        0
# age           0
# email         0
# phone         0
# city          0
# state         0
# country       0
# join_date     0
# dtype: int64

# %%
from src.validators import validate_missing_values

print(validate_missing_values)
# Out:
# <function validate_missing_values at 0x000001DA4D0054E0>

# %%
from src.validators import validate_duplicate_emails

print(validate_duplicate_emails)
# Out:
# <function validate_duplicate_emails at 0x000001DA4D004540>

# %%
import src.validators as validators

print(validators.__file__)
# Out:
# C:\Users\Welcome\Desktop\RetailIQ\Python\src\validators.py

# %%
import src.validators as validators

print(validators.__file__)
# Out:
# C:\Users\Welcome\Desktop\RetailIQ\Python\src\validators.py

# %%
import sys
from pathlib import Path

# Current folder: Python/notebooks
# Parent folder: Python
project_python = Path.cwd().parent.resolve()

if str(project_python) not in sys.path:
    sys.path.insert(0, str(project_python))

print(project_python)
# Out:
# C:\Users\Welcome\Desktop\RetailIQ\Python

# %%
import sys

print(sys.path[0])
# Out:
# C:\Users\Welcome\Desktop\RetailIQ\Python

# %%
from src.validators import (
    validate_missing_values,
    validate_duplicate_emails
)

# %%
validate_duplicate_emails(customers_df)
# Out:
# ...
# Duplicate Email Report
# ...
# ✅ No duplicate emails found.

# %%
from src.validators import (
    validate_missing_values,
    validate_duplicate_emails,
    validate_age_range,
    validate_gender,
)

# %%
validate_age_range(customers_df)
# Out:
# ...
# Age Validation Report
# ...
# ✅ All customer ages are valid.

# %%
import src.validators as validators

print(validators.__file__)
# Out:
# C:\Users\Welcome\Desktop\RetailIQ\Python\src\validators.py

# %%
import importlib
import src.validators as validators

importlib.reload(validators)
# Out:
# <module 'src.validators' from 'C:\\Users\\Welcome\\Desktop\\RetailIQ\\Python\\src\\validators.py'>

# %%
print(dir(validators))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'date', 'pd', 'run_customer_validations', 'validate_age_range', 'validate_duplicate_emails', 'validate_future_join_dates', 'validate_gender', 'validate_missing_values']

# %%
from src.validators import validate_gender
from datetime import date

# %%
validate_gender(customers_df)
# Out:
# ...
# Gender Validation Report
# ...
# ✅ All gender values are valid.

# %%
from src.validators import validate_future_join_dates

# %%
import importlib
import src.generators as generators

importlib.reload(generators)

customers_df = generators.generate_customers(1000)

# %%
print(customers_df["join_date"].dtype)
print(type(customers_df.loc[0, "join_date"]))
# Out:
# datetime64[s]
# <class 'pandas.Timestamp'>

# %%
print(customers_df["join_date"].dtype)
print(type(customers_df.loc[0, "join_date"]))
print(type(test_df.loc[0, "join_date"]))
# Out:
# datetime64[s]
# <class 'pandas.Timestamp'>
# <class 'pandas.Timestamp'>

# %%
customers_df["join_date"] = pd.to_datetime(customers_df["join_date"])

# %%
print(customers_df["join_date"].dtype)
print(type(customers_df.loc[0, "join_date"]))
# Out:
# datetime64[s]
# <class 'pandas.Timestamp'>

# %%
import importlib
import src.generators as generators

importlib.reload(generators)
# Out:
# <module 'src.generators' from 'C:\\Users\\Welcome\\Desktop\\RetailIQ\\Python\\src\\generators.py'>

# %%
customers_df = generators.generate_customers(1000)

# %%
print(customers_df["join_date"].dtype)
print(type(customers_df.loc[0, "join_date"]))
# Out:
# datetime64[s]
# <class 'pandas.Timestamp'>

# %%
test_df = customers_df.copy()

test_df.loc[0, "join_date"] = pd.Timestamp("2035-01-01")

validate_future_join_dates(test_df)
# Out:
# ...
# Checking Future Join Dates...
# Future Join Dates Found!
#   first_name last_name  gender  age                   email       phone  \
# 0     Robert    Sandal  Female   64  naiduayush@example.com  9093140830
#
#          city      state country  join_date
# 0  Kishanganj  Telangana   India 2035-01-01

# %%
from src.validators import run_customer_validations

# %%
run_customer_validations(customers_df)
# Out:
# ...
# Running Customer Validation Pipeline
# ...
# Missing Value Report
# ...
# first_name    0
# last_name     0
# gender        0
# age           0
# email         0
# phone         0
# city          0
# state         0
# country       0
# join_date     0
# dtype: int64
# ...
# Duplicate Email Report
# ...
# ✅ No duplicate emails found.
# ...
# Age Validation Report
# ...
# ✅ All customer ages are valid.
# ...
# Gender Validation Report
# ...
# ✅ All gender values are valid.
# ...
# Checking Future Join Dates...
# No Future Join Dates Found.
# ...
# Customer Validation Pipeline Completed
# ...

# %%
from pathlib import Path

from src.exporters import export_to_csv

# %%
project_root = Path.cwd().parent.parent

clean_data_dir = project_root / "Dataset" / "Clean_Data"

# %%
export_to_csv(
    df=customers_df,
    file_name="customers_clean.csv",
    output_dir=clean_data_dir
)
# Out:
# ...
# Dataset exported successfully!
# Location: c:\Users\Welcome\Desktop\RetailIQ\Dataset\Clean_Data\customers_clean.csv
# ...

# %%
from src.config import DB_HOST
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[156], line 1
# ----> 1 from src.config import DB_HOST
#
# ImportError: cannot import name 'DB_HOST' from 'src.config' (C:\Users\Welcome\Desktop\RetailIQ\Python\src\config.py)

# %%
from src.config import (
    DB_HOST,
    DB_PORT,
    DB_NAME,
    DB_USER,
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[154], line 1
# ----> 1 from src.config import (
#       2     DB_HOST,
#       3     DB_PORT,
#       4     DB_NAME,
#
# ImportError: cannot import name 'DB_HOST' from 'src.config' (C:\Users\Welcome\Desktop\RetailIQ\Python\src\config.py)

# %%
import src.config as config

print(config.__file__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import src.config as config
#       2
#       3 print(config.__file__)
#
# ModuleNotFoundError: No module named 'src'

# %%
import sys
from pathlib import Path

# Path to the Python folder
PROJECT_PYTHON = Path.cwd().parent.resolve()

if str(PROJECT_PYTHON) not in sys.path:
    sys.path.insert(0, str(PROJECT_PYTHON))

print("Python Path Added:", PROJECT_PYTHON)
# Out:
# Python Path Added: C:\Users\Welcome\Desktop\RetailIQ\Python

# %%
import src.config as config

print(config.DB_HOST)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import src.config as config
#       2
#       3 print(config.DB_HOST)
#
# File ~\Desktop\RetailIQ\Python\src\config.py:10
#       1 """
#       2 RetailIQ Configuration
#       3
#       4 Loads environment variables
#       5 used across the RetailIQ project.
#       6 """
#       8 from pathlib import Path
# ---> 10 from dotenv import load_dotenv
#      11 import os
#      13 # Project root directory
#
# ModuleNotFoundError: No module named 'dotenv'

# %%
import sys

print(sys.executable)
# Out:
# c:\Users\Welcome\Desktop\RetailIQ\.venv\Scripts\python.exe

# %%
# %pip install python-dotenv
# Out:
# ...
#   Using cached python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Using cached python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import src.config as config

print(config.DB_HOST)
# Out:
# None

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Welcome\Desktop\RetailIQ\.venv\Scripts\python.exe

# %%
import sys
from pathlib import Path

PROJECT_PYTHON = Path.cwd().parent.resolve()

if str(PROJECT_PYTHON) not in sys.path:
    sys.path.insert(0, str(PROJECT_PYTHON))

# %%
import src.config as config

print(config.DB_HOST)
print(config.DB_PORT)
print(config.DB_NAME)
print(config.DB_USER)
# Out:
# None
# None
# None
# None

# %%
import src.config as config

print(config.PROJECT_ROOT)
print(config.PROJECT_ROOT / ".env")
# Out:
# C:\Users\Welcome\Desktop\RetailIQ
# C:\Users\Welcome\Desktop\RetailIQ\.env

# %%
from pathlib import Path

env_path = Path(r"C:\Users\Welcome\Desktop\RetailIQ\.env")

print(env_path.exists())
# Out:
# True

# %%
from dotenv import dotenv_values

print(dotenv_values(r"C:\Users\Welcome\Desktop\RetailIQ\.env"))
# Out:
# OrderedDict({'DB_HOST': 'localhost', 'DB_PORT': '5432', 'DB_NAME': 'RetailIQ', 'DB_USER': 'postgres', 'DB_PASSWORD': 'Adhi@123'})

# %%
import src.config as config

print(config.DB_HOST)
print(config.DB_PORT)
print(config.DB_NAME)
print(config.DB_USER)
# Out:
# None
# None
# None
# None

# %%
from dotenv import dotenv_values

print(dotenv_values(r"C:\Users\Welcome\Desktop\RetailIQ\.env"))
# Out:
# OrderedDict({'DB_HOST': 'localhost', 'DB_PORT': '5432', 'DB_NAME': 'RetailIQ', 'DB_USER': 'postgres', 'DB_PASSWORD': 'Adhi@123'})

# %%
import importlib
import src.config as config

importlib.reload(config)

print(config.DB_HOST)
print(config.DB_PORT)
print(config.DB_NAME)
print(config.DB_USER)
# Out:
# localhost
# 5432
# RetailIQ
# postgres

# %%
import importlib
import src.database as database

importlib.reload(database)
# Out:
# <module 'src.database' from 'C:\\Users\\Welcome\\Desktop\\RetailIQ\\Python\\src\\database.py'>

# %%
import src.database as database

print(database.__file__)
# Out:
# C:\Users\Welcome\Desktop\RetailIQ\Python\src\database.py

# %%
import importlib
import src.database as database

importlib.reload(database)

engine = database.get_engine()
print(engine.url)
# Out:
# postgresql+psycopg2://postgres:***@localhost:5432/retailiq

# %%
with engine.connect() as conn:
    print("Connected!")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\Welcome\Desktop\RetailIQ\.venv\Lib\site-packages\sqlalchemy\engine\base.py:144, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 try:
# --> 144     self._dbapi_connection = engine.raw_connection()
#     145 except dialect.loaded_dbapi.Error as err:
#
# File c:\Users\Welcome\Desktop\RetailIQ\.venv\Lib\site-packages\sqlalchemy\engine\base.py:3319, in Engine.raw_connection(self)
#    3298 """Return a "raw" DBAPI connection from the connection pool.
#    3299
#    3300 The returned object is a proxied version of the DBAPI
#    (...)   3317
#    3318 """
# -> 3319 return self.pool.connect()
#
# File c:\Users\Welcome\Desktop\RetailIQ\.venv\Lib\site-packages\sqlalchemy\pool\base.py:448, in Pool.connect(self)
#     441 """Return a DBAPI connection from the pool.
# ...

# %%
engine = database.get_engine()

print(engine)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 engine = database.get_engine()
#       2
#       3 print(engine)
#
# AttributeError: module 'src.database' has no attribute 'get_engine'

# %%
import src.database as database

print(database.__file__)
print(dir(database))
# Out:
# C:\Users\Welcome\Desktop\RetailIQ\Python\src\database.py
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__']

# %%
from pathlib import Path

print(Path("C:/Users/Welcome/Desktop/RetailIQ/Python/src/database.py").read_text())

# %%
import importlib
import src.database as database

importlib.reload(database)

print(database.__file__)
print(dir(database))
# Out:
# C:\Users\Welcome\Desktop\RetailIQ\Python\src\database.py
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__']

# %%
from pathlib import Path

print(Path("C:/Users/Welcome/Desktop/RetailIQ/Python/src/database.py").read_text())

# %%
import sys

if "src.database" in sys.modules:
    del sys.modules["src.database"]

import src.database as database

print(database.__file__)
print(dir(database))
# Out:
# C:\Users\Welcome\Desktop\RetailIQ\Python\src\database.py
# ['DB_HOST', 'DB_NAME', 'DB_PASSWORD', 'DB_PORT', 'DB_USER', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'create_engine', 'get_engine']

# %%
from pathlib import Path

file_path = Path(r"C:\Users\Welcome\Desktop\RetailIQ\Python\src\database.py")

print(file_path.exists())
print(file_path.read_text())
# Out:
# True

# %%
import importlib
import src.database as database

importlib.reload(database)
# Out:
# <module 'src.database' from 'C:\\Users\\Welcome\\Desktop\\RetailIQ\\Python\\src\\database.py'>

# %%
from pathlib import Path

file_path = Path(r"C:\Users\Welcome\Desktop\RetailIQ\Python\src\database.py")

print(file_path.stat().st_size)
# Out:
# 485

# %%
import importlib
import src.database as database

importlib.reload(database)

engine = database.get_engine()

with engine.connect() as conn:
    print("✅ Connected successfully")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\Welcome\Desktop\RetailIQ\.venv\Lib\site-packages\sqlalchemy\engine\base.py:144, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 try:
# --> 144     self._dbapi_connection = engine.raw_connection()
#     145 except dialect.loaded_dbapi.Error as err:
#
# File c:\Users\Welcome\Desktop\RetailIQ\.venv\Lib\site-packages\sqlalchemy\engine\base.py:3319, in Engine.raw_connection(self)
#    3298 """Return a "raw" DBAPI connection from the connection pool.
#    3299
#    3300 The returned object is a proxied version of the DBAPI
#    (...)   3317
#    3318 """
# -> 3319 return self.pool.connect()
#
# File c:\Users\Welcome\Desktop\RetailIQ\.venv\Lib\site-packages\sqlalchemy\pool\base.py:448, in Pool.connect(self)
#     441 """Return a DBAPI connection from the pool.
# ...

# %%
from pathlib import Path

print(Path.cwd())
# Out:
# c:\Users\Welcome\Desktop\RetailIQ\Python\notebooks

# %%
import sys
from pathlib import Path

project_python = Path.cwd()

if str(project_python) not in sys.path:
    sys.path.insert(0, str(project_python))

print(project_python)
# Out:
# c:\Users\Welcome\Desktop\RetailIQ\Python\notebooks

# %%
import src.database as database

print("✅ src imported successfully")
# Out:
# ✅ src imported successfully

# %%
from src.database import get_engine

engine = get_engine()

with engine.connect() as conn:
    print("✅ Database Connected Successfully")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from src.database import get_engine
#       2
#       3 engine = get_engine()
#       4
#
# ModuleNotFoundError: No module named 'src'

# %%
from pathlib import Path

print("Current directory:", Path.cwd())
print("Does src exist here?", (Path.cwd() / "src").exists())
print("Does src exist one level above?", (Path.cwd().parent / "src").exists())
# Out:
# Current directory: c:\Users\Welcome\Desktop\RetailIQ\Python\notebooks
# Does src exist here? False
# Does src exist one level above? True

# %%
import sys

print(sys.path[0:3])
# Out:
# ['C:\\Users\\Welcome\\Desktop\\RetailIQ\\Python', 'C:\\Users\\Welcome\\AppData\\Local\\Programs\\Python\\Python312\\python312.zip', 'C:\\Users\\Welcome\\AppData\\Local\\Programs\\Python\\Python312\\DLLs']

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Welcome\Desktop\RetailIQ\.venv\Scripts\python.exe

# %%
import os
import sys
from pathlib import Path

print("="*50)
print("Current Working Directory")
print("="*50)
print(Path.cwd())

print("\n" + "="*50)
print("Files in Current Directory")
print("="*50)
print(os.listdir())

print("\n" + "="*50)
print("Python Path")
print("="*50)
for p in sys.path:
    print(p)

print("\n" + "="*50)
print("src exists here?")
print("="*50)
print((Path.cwd()/"src").exists())
print((Path.cwd().parent/"src").exists())
# Out:
# ...
# Current Working Directory
# ...
# c:\Users\Welcome\Desktop\RetailIQ\Python\notebooks
#
# ...
# Files in Current Directory
# ...
# ['00_test_environment.ipynb', '01_generate_customers.ipynb', '02_generate_products.ipynb', '03_generate_employees.ipynb', '04_generate_inventory.ipynb', '05_generate_date_dimension.ipynb', '06_generate_orders.ipynb', '07_generate_order_items.ipynb', '08_load_to_postgresql.ipynb']
#
# ...
# Python Path
# ...
# C:\Users\Welcome\AppData\Local\Programs\Python\Python312\python312.zip
# C:\Users\Welcome\AppData\Local\Programs\Python\Python312\DLLs
# C:\Users\Welcome\AppData\Local\Programs\Python\Python312\Lib
# C:\Users\Welcome\AppData\Local\Programs\Python\Python312
# c:\Users\Welcome\Desktop\RetailIQ\.venv
#
# c:\Users\Welcome\Desktop\RetailIQ\.venv\Lib\site-packages
#
# ...
# src exists here?
# ...
# False
# True

# %%
print("✅ Imports successful")
# Out:
# ✅ Imports successful

# %%
import sys
from pathlib import Path

project_python = Path.cwd().parent.resolve()

if str(project_python) not in sys.path:
    sys.path.insert(0, str(project_python))

print("Added:", project_python)
print("sys.path[0]:", sys.path[0])
# Out:
# Added: C:\Users\Welcome\Desktop\RetailIQ\Python
# sys.path[0]: C:\Users\Welcome\Desktop\RetailIQ\Python

# %%
import sys
print(sys.path[:3])
# Out:
# ['C:\\Users\\Welcome\\Desktop\\RetailIQ\\Python', 'C:\\Users\\Welcome\\AppData\\Local\\Programs\\Python\\Python312\\python312.zip', 'C:\\Users\\Welcome\\AppData\\Local\\Programs\\Python\\Python312\\DLLs']

# %%
import src.database as database

print("✅ Import successful")
# Out:
# ✅ Import successful

# %%
from src.database import get_engine

engine = get_engine()

with engine.connect() as conn:
    print("✅ Database Connected Successfully")
# Out:
# ✅ Database Connected Successfully
