# %%
from src.config import *

print(PROJECT_ROOT)
print(RAW_DATA_PATH)
print(CUSTOMER_COUNT)

# %%
import sys
from pathlib import Path

# Get the Python folder
project_python = Path.cwd().parent

# Add it to Python path
sys.path.append(str(project_python))

# %%
from src.config import *

print(PROJECT_ROOT)
print(RAW_DATA_PATH)
print(CUSTOMER_COUNT)
# Out:
# C:\Users\Welcome\Desktop\RetailIQ
# C:\Users\Welcome\Desktop\RetailIQ\Dataset\Raw
# 5000
